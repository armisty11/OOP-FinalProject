# %%
import sys
sys.path.append('../')

from DataHabit.task_data import TaskData

class BehaviorAnalyzer(TaskData):
    """Analyzes and classifies student behavior patterns."""

    def __init__(self, student_id, task_name, submission_time):
        super().__init__(student_id, task_name, submission_time)
        self._behavior_label = None

    def classify_behavior(self):
        """Classify students as Procrastinator, Consistent, etc."""
        pass  # TODO: implement classification logic

    def get_statistics(self):
        """Summarize average submission delay and consistency."""
        pass  # TODO: calculate behavior stats

    def __str__(self):
        return f"BehaviorAnalyzer({self._student_id}, label={self._behavior_label})"
